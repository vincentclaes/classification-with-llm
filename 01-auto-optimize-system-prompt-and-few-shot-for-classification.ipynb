# %% [markdown]
# # Atuomatically Optimize Prompts + Few Shot Examples for Classification

# %%
import pandas as pd

# !pip install 'adalflow[openai]' torch datasets matplotlib --quiet

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
# [{'class_name': 'ORDER',
#   'question': 'i have to add some items to purchase {{Order Number}} help me',
#   'id': 1726},
#  {'class_name': 'ACCOUNT',
#   'question': 'I would like to close my standard account, can you help me?',
#   'id': 11398},
#  {'class_name': 'DELIVERY',
#   'question': 'where do I see when my item is going to arrive?',
#   'id': 13395},
#  {'class_name': 'SHIPPING',
#   'question': 'I want help setting up my delivery address',
#   'id': 22899},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'i want assistance cancelling the newsletter subscription',
#   'id': 17094},
#  {'class_name': 'REFUND',
#   'question': 'how to see the status of my restitution?',
#   'id': 26473},
#  {'class_name': 'ORDER',
#   'question': 'help swapping some products of order {{Order Number}}',
#   'id': 1738},
#  {'class_name': 'ORDER',
#   'question': 'i cant add an article to order {{Order Number}}',
#   'id': 1973},
#  {'class_name': 'ACCOUNT',
#   'question': 'i have got to retrieve the pwd of my user account',
#   'id': 20570},
#  {'class_name': 'INVOICE',
#   'question': 'need assistance to find the fucking invoices from {{Person Name}}',
#   'id': 4334},
#  {'class_name': 'CANCEL',
#   'question': 'i want assistance checking the termination penalties',
#   'id': 3648},
#  {'class_name': 'INVOICE',
#   'question': 'check invoices from last month',
#   'id': 4129},
#  {'class_name': 'INVOICE',
#   'question': 'I do not know how to get my invoices from {{Person Name}}',
#   'id': 15170},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I need to unsubscribe from the newsletter, can yyou help me?',
#   'id': 17688},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I have got to subscribe to the corporate newsletter',
#   'id': 17693},
#  {'class_name': 'DELIVERY',
#   'question': 'i call to check when will my article arrive',
#   'id': 12914},
#  {'class_name': 'CONTACT',
#   'question': 'help me chat with someone',
#   'id': 9379},
#  {'class_name': 'DELIVERY',
#   'question': 'I want help to check how soon can I expect my package',
#   'id': 13334},
#  {'class_name': 'ACCOUNT',
#   'question': 'modifying ingormation on {{Account Category}} account',
#   'id': 14284},
#  {'class_name': 'CANCEL',
#   'question': 'how to see the early exit charge?',
#   'id': 3031},
#  {'class_name': 'DELIVERY',
#   'question': 'help me checking what shipping methods you offer',
#   'id': 12388},
#  {'class_name': 'SHIPPING',
#   'question': 'need assistance to update the shipping address',
#   'id': 2249},
#  {'class_name': 'DELIVERY',
#   'question': 'where to see what delivery options uoffer',
#   'id': 12247},
#  {'class_name': 'INVOICE',
#   'question': 'wanna see my bill from {{Person Name}}',
#   'id': 4569},
#  {'class_name': 'REFUND',
#   'question': 'help me to request a rebate of my money',
#   'id': 16743},
#  {'class_name': 'PAYMENT',
#   'question': 'want assistance reporting troubles with payment',
#   'id': 18166},
#  {'class_name': 'FEEDBACK',
#   'question': 'where do i file an customer claim against ur business',
#   'id': 7151},
#  {'class_name': 'INVOICE',
#   'question': 'how can I give a quick look at my invoice #12588?',
#   'id': 4822},
#  {'class_name': 'FEEDBACK',
#   'question': 'do you have an e-mail to submit an opinion about a product?',
#   'id': 22062},
#  {'class_name': 'SHIPPING',
#   'question': 'problem submitting the shipping address',
#   'id': 23301},
#  {'class_name': 'INVOICE',
#   'question': 'I want assistance locating my invoices from {{Person Name}}',
#   'id': 4157},
#  {'class_name': 'FEEDBACK',
#   'question': 'i want help sending some feedback about a product',
#   'id': 22219},
#  {'class_name': 'PAYMENT',
#   'question': 'how to inform of a problem with online payments?',
#   'id': 18176},
#  {'class_name': 'INVOICE',
#   'question': "I don't know what I need to do to look forthe invoice #12588",
#   'id': 4663},
#  {'class_name': 'SHIPPING',
#   'question': 'where do I enter my secondary delivery address?',
#   'id': 23285},
#  {'class_name': 'FEEDBACK',
#   'question': 'making customer complaint',
#   'id': 7624},
#  {'class_name': 'SHIPPING',
#   'question': 'I entered a wrong address, will you help me update it?',
#   'id': 2095},
#  {'class_name': 'INVOICE',
#   'question': 'download bills from {{Person Name}}',
#   'id': 14939},
#  {'class_name': 'FEEDBACK',
#   'question': 'need to leave feedback for a product',
#   'id': 22685},
#  {'class_name': 'DELIVERY',
#   'question': 'wanna see what delivery options are there i need help',
#   'id': 12334},
#  {'class_name': 'CONTACT',
#   'question': 'I have to talk to an assistant, help me',
#   'id': 9384},
#  {'class_name': 'FEEDBACK',
#   'question': 'I need help to file a customer claim against your business',
#   'id': 7673},
#  {'class_name': 'PAYMENT',
#   'question': 'what do I have to do to notify of payment issues?',
#   'id': 18348},
#  {'class_name': 'CONTACT',
#   'question': 'I have to speak with a person',
#   'id': 9161},
#  {'class_name': 'ACCOUNT',
#   'question': 'need to update my account can i get some help',
#   'id': 14166},
#  {'class_name': 'CANCEL',
#   'question': 'i want help to see the termination charges',
#   'id': 3583},
#  {'class_name': 'INVOICE',
#   'question': 'I call to get my bills from {{Person Name}}',
#   'id': 15486},
#  {'class_name': 'INVOICE',
#   'question': 'chck bill from {{Person Name}}',
#   'id': 4149},
#  {'class_name': 'CANCEL',
#   'question': 'I want assistance checking the early termination penalty',
#   'id': 3078},
#  {'class_name': 'SHIPPING',
#   'question': 'i do not know what i need to do to correct my address',
#   'id': 2538},
#  {'class_name': 'ORDER',
#   'question': 'edtiing order {{Order Number}}',
#   'id': 1417},
#  {'class_name': 'CANCEL',
#   'question': 'help checking the termmination fees',
#   'id': 3498},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I want to unsubscribe to your newsletter, I need help',
#   'id': 17421},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'help me unsubscribe from ur corporate newsletter',
#   'id': 17517},
#  {'class_name': 'SHIPPING',
#   'question': 'problem setting up a secondary delivery address',
#   'id': 23231},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'need to receive the damn newsletter will uhelp me',
#   'id': 17718},
#  {'class_name': 'PAYMENT',
#   'question': 'how can I notify of an error with online payment?',
#   'id': 17948},
#  {'class_name': 'ORDER',
#   'question': 'add something to order {{Order Number}}',
#   'id': 1071},
#  {'class_name': 'PAYMENT',
#   'question': 'i want assistance to list ur available payment modalities',
#   'id': 5628},
#  {'class_name': 'SHIPPING',
#   'question': 'can i submit the secondary delivery address',
#   'id': 23279},
#  {'class_name': 'DELIVERY',
#   'question': 'is it possible toorder from {{Delivery City}}',
#   'id': 12221},
#  {'class_name': 'REFUND',
#   'question': 'i expect a reimbursxement of {{Currency Symbol}}{{Refund Amount}}',
#   'id': 25987},
#  {'class_name': 'INVOICE',
#   'question': 'assistance to look for the bill from {{Person Name}}',
#   'id': 4225},
#  {'class_name': 'ACCOUNT',
#   'question': 'can I open a gold account?',
#   'id': 10713},
#  {'class_name': 'ORDER',
#   'question': 'I have got to locate purchase {{Order Number}}, I need help',
#   'id': 25740},
#  {'class_name': 'CANCEL',
#   'question': 'I tryh to check the termination fees',
#   'id': 3012},
#  {'class_name': 'CONTACT',
#   'question': 'how do I talk with somebody?',
#   'id': 9872},
#  {'class_name': 'SHIPPING',
#   'question': 'is it possible to set a different shipping address up?',
#   'id': 23400},
#  {'class_name': 'CANCEL',
#   'question': 'can I check the early termination fee?',
#   'id': 3775},
#  {'class_name': 'CONTACT',
#   'question': 'can you help me contact a human agent?',
#   'id': 9261},
#  {'class_name': 'ACCOUNT',
#   'question': 'I need information about the termination of a pro account',
#   'id': 11547},
#  {'class_name': 'ORDER',
#   'question': 'I need help cancelling order {{Order Number}}',
#   'id': 229},
#  {'class_name': 'ACCOUNT',
#   'question': 'editing info on pro account',
#   'id': 14801},
#  {'class_name': 'INVOICE',
#   'question': 'how to locate my bill #12588?',
#   'id': 3967},
#  {'class_name': 'INVOICE',
#   'question': 'help me checking my bill from {{Person Name}}',
#   'id': 4130},
#  {'class_name': 'FEEDBACK',
#   'question': 'do you have a section to leave a comment for your company?',
#   'id': 22019},
#  {'class_name': 'FEEDBACK',
#   'question': 'do you have a method to submit a review for your services?',
#   'id': 21938},
#  {'class_name': 'INVOICE',
#   'question': 'need help downloading the invoices from {{Person Name}}',
#   'id': 14928},
#  {'class_name': 'PAYMENT',
#   'question': 'will utell me the accepted payment options',
#   'id': 4967},
#  {'class_name': 'CANCEL',
#   'question': 'I try to see the termination fee',
#   'id': 3056},
#  {'class_name': 'ORDER',
#   'question': 'I want help to cancel purchase {{Order Number}}',
#   'id': 864},
#  {'class_name': 'ACCOUNT',
#   'question': 'inform of a problem with sign-up',
#   'id': 21430},
#  {'class_name': 'REFUND',
#   'question': 'reimbursing {{Currency Symbol}}{{Refund Amount}}',
#   'id': 16713},
#  {'class_name': 'CANCEL',
#   'question': "I can't find the early exit penalty, will you help me?",
#   'id': 3754},
#  {'class_name': 'INVOICE',
#   'question': 'I do not know what I have to do to download the bill #85632',
#   'id': 15884},
#  {'class_name': 'PAYMENT',
#   'question': 'i want help seeing what payment methods uaccept',
#   'id': 5017},
#  {'class_name': 'ORDER',
#   'question': 'is it possible to acquire several of ur article',
#   'id': 19473},
#  {'class_name': 'ACCOUNT',
#   'question': 'how do I use the premium profile?',
#   'id': 24185},
#  {'class_name': 'FEEDBACK',
#   'question': 'can you help me tyo send my feedback for a service?',
#   'id': 22438},
#  {'class_name': 'CANCEL',
#   'question': 'I need assistance to check the termination charges',
#   'id': 3678},
#  {'class_name': 'PAYMENT',
#   'question': 'could you help me to report an error with online payment?',
#   'id': 17970},
#  {'class_name': 'CANCEL',
#   'question': "I don't know how to see the withdrawal charge",
#   'id': 3279},
#  {'class_name': 'PAYMENT', 'question': 'payment issues', 'id': 18093},
#  {'class_name': 'DELIVERY',
#   'question': 'assistance to check hw soon can i expect the order',
#   'id': 13011},
#  {'class_name': 'INVOICE',
#   'question': 'what do I need to do to get my goddamn bill from {{Person Name}}?',
#   'id': 15843},
#  {'class_name': 'REFUND',
#   'question': "I'd like to check in which situations can i ask for a refund",
#   'id': 6319},
#  {'class_name': 'SHIPPING',
#   'question': 'supports editing the address',
#   'id': 2514},
#  {'class_name': 'PAYMENT',
#   'question': 'help me listing the available payment options',
#   'id': 5027},
#  {'class_name': 'REFUND',
#   'question': 'i dont know how to receive a refund of my money',
#   'id': 16761},
#  {'class_name': 'SHIPPING',
#   'question': 'I need to update the address',
#   'id': 2434},
#  {'class_name': 'ACCOUNT',
#   'question': 'i do not have a {{Account Type}} account ned help creating one',
#   'id': 10141},
#  {'class_name': 'FEEDBACK',
#   'question': 'i dont know what to do to fgile a consumer claim',
#   'id': 7221},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I want assistance to sign up to the company newsletter',
#   'id': 17767},
#  {'class_name': 'INVOICE',
#   'question': 'I have to look for my bill #85632, could I get some help?',
#   'id': 4207},
#  {'class_name': 'DELIVERY',
#   'question': 'I need to check how long it takes for my shipment to arrive',
#   'id': 12904},
#  {'class_name': 'CONTACT',
#   'question': 'uhave a free of charge number to talk with customer support',
#   'id': 8490},
#  {'class_name': 'REFUND',
#   'question': 'I have to see in what cases can I request refunds, help me',
#   'id': 6706},
#  {'class_name': 'INVOICE',
#   'question': 'I want to give a quick look at my bill #00108, help me',
#   'id': 4188},
#  {'class_name': 'FEEDBACK',
#   'question': 'I need to file a customer reclamation, how do I do it?',
#   'id': 7659},
#  {'class_name': 'CONTACT',
#   'question': 'assistance speaking to someone',
#   'id': 9778},
#  {'class_name': 'REFUND',
#   'question': 'want help checking in wht situations can i request refunds',
#   'id': 6213},
#  {'class_name': 'ACCOUNT',
#   'question': 'I cannot remember the key of my profile, help me recover it',
#   'id': 20840},
#  {'class_name': 'ORDER',
#   'question': "I don't know how to shop some of your item",
#   'id': 19652},
#  {'class_name': 'CANCEL',
#   'question': 'can ya help me seeing the terminatio penalties',
#   'id': 3233},
#  {'class_name': 'SUBSCRIPTION', 'question': 'ya have newsletter', 'id': 16981},
#  {'class_name': 'ORDER',
#   'question': 'add an item to order {{Order Number}}',
#   'id': 1272},
#  {'class_name': 'ORDER', 'question': 'order anitem', 'id': 19186},
#  {'class_name': 'ORDER',
#   'question': 'want assistance to cancel order  {{Order Number}}',
#   'id': 32},
#  {'class_name': 'ORDER',
#   'question': 'need  to check the eta of the purchase {{Order Number}} help me',
#   'id': 25126},
#  {'class_name': 'PAYMENT',
#   'question': 'want assistance solving a payment issue',
#   'id': 18798},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I do not know how to sign up to the corporate newsletter',
#   'id': 17618},
#  {'class_name': 'CONTACT',
#   'question': "I don't know how I can speak with a goddamn person",
#   'id': 9869},
#  {'class_name': 'REFUND',
#   'question': 'I am waiting for a restitution of {{Currency Symbol}}{{Refund Amount}}',
#   'id': 26283},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'assistance subscribing to your newsletter',
#   'id': 17320},
#  {'class_name': 'PAYMENT',
#   'question': 'I need assistamce to inform of a payment issue',
#   'id': 18446},
#  {'class_name': 'DELIVERY',
#   'question': 'how could I see how soon can I expect my order?',
#   'id': 13830},
#  {'class_name': 'REFUND',
#   'question': "I can't see if there is anything new on the compensation",
#   'id': 26561},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I do not know how I can sign up to the goddamn newsletter',
#   'id': 17683},
#  {'class_name': 'SHIPPING',
#   'question': 'i need help chanigng the shipping address',
#   'id': 2594},
#  {'class_name': 'FEEDBACK',
#   'question': 'need help leaving a comment about your services',
#   'id': 22163},
#  {'class_name': 'SHIPPING',
#   'question': 'help trying to edit my delivery address',
#   'id': 2550},
#  {'class_name': 'INVOICE',
#   'question': "I don't know what to do ti see my invoice from {{Person Name}}",
#   'id': 4329},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'where do I sign up to your newsletter?',
#   'id': 17775},
#  {'class_name': 'INVOICE',
#   'question': 'seebills from {{Person Name}}',
#   'id': 4502},
#  {'class_name': 'DELIVERY',
#   'question': 'do you edliver to {{Delivery Country}}?',
#   'id': 12136},
#  {'class_name': 'ACCOUNT',
#   'question': 'can you help me switching to the pro account?',
#   'id': 24047},
#  {'class_name': 'CONTACT',
#   'question': 'help me see what hhours I can call customer assistance',
#   'id': 8296},
#  {'class_name': 'DELIVERY',
#   'question': 'help me checking what delivery methods I have',
#   'id': 12138},
#  {'class_name': 'ORDER',
#   'question': 'help me to buy several of ur article',
#   'id': 19070},
#  {'class_name': 'DELIVERY',
#   'question': 'need help to see when my product is gonna arrive',
#   'id': 13030},
#  {'class_name': 'REFUND',
#   'question': 'i have got to see in which cases can i request my money back',
#   'id': 6128},
#  {'class_name': 'ACCOUNT',
#   'question': 'need assistance notifying of an issue with sign-up',
#   'id': 21140},
#  {'class_name': 'FEEDBACK',
#   'question': 'i need help to file a consumer complaint',
#   'id': 7448},
#  {'class_name': 'ORDER',
#   'question': 'problems with correcting order {{Order Number}}',
#   'id': 1564},
#  {'class_name': 'PAYMENT',
#   'question': 'help informing of a problem with online payments',
#   'id': 18703},
#  {'class_name': 'CONTACT',
#   'question': 'assistance checking what hours I can call customer service',
#   'id': 8800},
#  {'class_name': 'FEEDBACK',
#   'question': 'help me file a claim agazinst ur company',
#   'id': 7876},
#  {'class_name': 'INVOICE',
#   'question': 'I want help taking a quick look at bill #85632',
#   'id': 4356},
#  {'class_name': 'SHIPPING',
#   'question': 'I need to set a secondary delivery address up, help me',
#   'id': 23178},
#  {'class_name': 'ORDER',
#   'question': 'how do i remove several articles from order {{Order Number}}',
#   'id': 1798},
#  {'class_name': 'REFUND',
#   'question': "I'm waiting for a compensation of {{Refund Amount}} dollars",
#   'id': 26006},
#  {'class_name': 'FEEDBACK',
#   'question': 'I need assistance leaving a review about a service',
#   'id': 22819},
#  {'class_name': 'FEEDBACK',
#   'question': 'need help submitting bloody feedback for a service',
#   'id': 22168},
#  {'class_name': 'SHIPPING',
#   'question': 'I have a trouble trying to change my delivery address',
#   'id': 2130},
#  {'class_name': 'CONTACT',
#   'question': "I don't understand you, how could I chat with a damn person?",
#   'id': 9694},
#  {'class_name': 'DELIVERY',
#   'question': 'how to see what delivery options you offer?',
#   'id': 12657},
#  {'class_name': 'REFUND',
#   'question': 'help seeing in what cases can i request refunds',
#   'id': 6271},
#  {'class_name': 'REFUND',
#   'question': 'I paid {{Currency Symbol}}{{Refund Amount}} for these articles, where do I obtain a rebate?',
#   'id': 16787},
#  {'class_name': 'SHIPPING',
#   'question': 'support coprrecting the address',
#   'id': 2018},
#  {'class_name': 'REFUND',
#   'question': 'i dont know what i need to do to see ur reimbursement policy',
#   'id': 6567},
#  {'class_name': 'ORDER',
#   'question': 'I have got to track purchase {{Order Number}}',
#   'id': 25079},
#  {'class_name': 'DELIVERY',
#   'question': 'I need assistance checking how soon can I expect my delivery',
#   'id': 13353},
#  {'class_name': 'ACCOUNT',
#   'question': 'help using the {{Account Type}} profile',
#   'id': 24059},
#  {'class_name': 'CONTACT',
#   'question': 'how to speak with somebody ?',
#   'id': 9199},
#  {'class_name': 'REFUND',
#   'question': 'I want assistance to see the status of the compensation',
#   'id': 26286},
#  {'class_name': 'DELIVERY',
#   'question': 'I am trying to see what options for delivery are there',
#   'id': 12826},
#  {'class_name': 'INVOICE',
#   'question': "I don't know what I need to do to get the bill #37777",
#   'id': 15157},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'where to subscribe to the newsletter ?',
#   'id': 17154},
#  {'class_name': 'CONTACT',
#   'question': 'help me checking at what time I can contact customer support',
#   'id': 8532},
#  {'class_name': 'CONTACT',
#   'question': 'i need assistance to speak to an operator',
#   'id': 9723},
#  {'class_name': 'SHIPPING',
#   'question': 'help to submit a secondary delivery address',
#   'id': 23475},
#  {'class_name': 'REFUND',
#   'question': 'I donot know what to do to demand a refund',
#   'id': 16582},
#  {'class_name': 'CONTACT',
#   'question': "you aren't helpful at all, help me speaking to a person",
#   'id': 9389},
#  {'class_name': 'DELIVERY',
#   'question': 'how do I check the methods for shipping?',
#   'id': 12522},
#  {'class_name': 'INVOICE',
#   'question': 'can you help me downloading invoice #12588?',
#   'id': 15171},
#  {'class_name': 'CONTACT',
#   'question': 'I want assistance chatting with an operator',
#   'id': 9546},
#  {'class_name': 'REFUND',
#   'question': 'help me see in which situations cani ask to be refunded',
#   'id': 6746},
#  {'class_name': 'DELIVERY',
#   'question': 'i need assistance to see when will my product arrive',
#   'id': 13759},
#  {'class_name': 'SHIPPING',
#   'question': 'where can I get information about an address correction ?',
#   'id': 2409},
#  {'class_name': 'FEEDBACK',
#   'question': 'help me lodging a customer complaint against your business',
#   'id': 7818},
#  {'class_name': 'INVOICE',
#   'question': 'how to download the bills from {{Person Name}}?',
#   'id': 15045},
#  {'class_name': 'SHIPPING',
#   'question': 'my shipping address has changed how can i modify it',
#   'id': 2702},
#  {'class_name': 'FEEDBACK',
#   'question': 'how to send some feedback about your company?',
#   'id': 22426},
#  {'class_name': 'ORDER',
#   'question': 'i do not know what i need to do to buy several items',
#   'id': 18900},
#  {'class_name': 'SHIPPING',
#   'question': 'help me set my goddamn delivery address up',
#   'id': 23026},
#  {'class_name': 'PAYMENT',
#   'question': "I don't know what I need to do to report a payment problem",
#   'id': 18274},
#  {'class_name': 'PAYMENT',
#   'question': 'where can I list your accepted payment options?',
#   'id': 5329},
#  {'class_name': 'REFUND',
#   'question': 'i do not know what to do to receive restitutions of money',
#   'id': 16698},
#  {'class_name': 'PAYMENT',
#   'question': 'how t see the allowed payment methods',
#   'id': 5569},
#  {'class_name': 'CONTACT',
#   'question': 'wanna see what hours cdustomer support available is',
#   'id': 8334},
#  {'class_name': 'ORDER',
#   'question': 'I need to add some articles to purchase {{Order Number}}',
#   'id': 1034},
#  {'class_name': 'ACCOUNT',
#   'question': 'give me information about the deletion of my {{Account Type}} account',
#   'id': 11522},
#  {'class_name': 'DELIVERY',
#   'question': 'want help checking when will my product arrive',
#   'id': 13175},
#  {'class_name': 'FEEDBACK',
#   'question': 'can you help me make a complaint against your company?',
#   'id': 7256},
#  {'class_name': 'INVOICE',
#   'question': 'i dont know what to do tgo download the bill #12588',
#   'id': 15510},
#  {'class_name': 'ORDER',
#   'question': 'I do not know how to earn several of your item',
#   'id': 19750},
#  {'class_name': 'REFUND',
#   'question': 'I need to see if there is anything new on the compensation',
#   'id': 26696},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I would like to unsubscribe to the company newsletter',
#   'id': 17175},
#  {'class_name': 'INVOICE',
#   'question': 'I would like to get the bill from {{Person Name}}, help me',
#   'id': 15618},
#  {'class_name': 'DELIVERY',
#   'question': 'is it plssible to order from {{Delivery Country}}?',
#   'id': 12648},
#  {'class_name': 'CONTACT',
#   'question': 'I try to see at what time I can reach customer support',
#   'id': 8818},
#  {'class_name': 'DELIVERY',
#   'question': 'I want assistance seeing the methods for shipment',
#   'id': 12142},
#  {'class_name': 'REFUND',
#   'question': 'help knowing if there is anything new on the restitution',
#   'id': 25912},
#  {'class_name': 'INVOICE',
#   'question': 'wanna download invoice #85632',
#   'id': 15332},
#  {'class_name': 'FEEDBACK',
#   'question': 'i call to leave some feedack',
#   'id': 22246},
#  {'class_name': 'ORDER',
#   'question': 'i have problems with canceling order {{Order Number}}',
#   'id': 196},
#  {'class_name': 'INVOICE', 'question': 'see bill #37777', 'id': 4804},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'how to sign up to your newsletter?',
#   'id': 17591},
#  {'class_name': 'REFUND',
#   'question': 'I am waiting for a restitution of {{Refund Amount}} dollars',
#   'id': 26156},
#  {'class_name': 'DELIVERY',
#   'question': 'can you help me check how oson can I expect the parcel?',
#   'id': 13436},
#  {'class_name': 'INVOICE',
#   'question': 'I do not know what I need to do to get the invoice #85632',
#   'id': 15745},
#  {'class_name': 'SHIPPING',
#   'question': 'howq can i set up the secondary delivery address',
#   'id': 23527},
#  {'class_name': 'CANCEL',
#   'question': 'i do not know how to check the early termination fee',
#   'id': 3186},
#  {'class_name': 'DELIVERY',
#   'question': 'can you show me how soon can I expect the shipment?',
#   'id': 13349},
#  {'class_name': 'SHIPPING',
#   'question': 'i have sisues setting up my secondary shipping address',
#   'id': 23692},
#  {'class_name': 'INVOICE',
#   'question': 'where can I give a quick look at invoice #37777?',
#   'id': 4169},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'can you help me unsubscribe to the newsletter?',
#   'id': 16973},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'can I cancel my corporate newsletter subscription?',
#   'id': 16949},
#  {'class_name': 'SHIPPING',
#   'question': 'set new shipping address up',
#   'id': 23792},
#  {'class_name': 'SHIPPING',
#   'question': 'how do I enter a secondary delivery address?',
#   'id': 23129},
#  {'class_name': 'DELIVERY',
#   'question': 'wanna see what shipment methods i can choose how do i do it',
#   'id': 12854},
#  {'class_name': 'REFUND',
#   'question': 'I expect a restitution of {{Refund Amount}} dollars',
#   'id': 26177},
#  {'class_name': 'PAYMENT',
#   'question': 'i canr pay can ya help me report issues with online payment',
#   'id': 18559},
#  {'class_name': 'PAYMENT',
#   'question': 'need assistance solving an issue with online paymenst',
#   'id': 18569},
#  {'class_name': 'CONTACT',
#   'question': 'can I talk with an assistant?',
#   'id': 9194},
#  {'class_name': 'FEEDBACK',
#   'question': 'want help making a claim against ur organization',
#   'id': 7685},
#  {'class_name': 'CONTACT',
#   'question': 'I want to see at what time I can contact customer assistance',
#   'id': 8699},
#  {'class_name': 'CANCEL', 'question': 'show withdrawal fees', 'id': 3109},
#  {'class_name': 'FEEDBACK',
#   'question': 'i call to lodge a customer complaint against ur organization',
#   'id': 7334},
#  {'class_name': 'REFUND',
#   'question': 'i do not know how i can ask for rebates',
#   'id': 16459},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I want assistance to subscribe to your company newsletter',
#   'id': 17610},
#  {'class_name': 'ACCOUNT',
#   'question': 'help me open a {{Account Category}} account for my dad',
#   'id': 10478},
#  {'class_name': 'ORDER',
#   'question': 'how to add an article to purchase {{Order Number}}?',
#   'id': 1650},
#  {'class_name': 'ORDER',
#   'question': 'when will purchase {{Order Number}} arrive',
#   'id': 25116},
#  {'class_name': 'ACCOUNT',
#   'question': 'I no longer need the user, can I remove it?',
#   'id': 11334},
#  {'class_name': 'CANCEL',
#   'question': 'need help seeing the termination chaeges',
#   'id': 3166},
#  {'class_name': 'INVOICE',
#   'question': 'I want assistance to give a quick look at the invoice #37777',
#   'id': 4224},
#  {'class_name': 'ORDER',
#   'question': 'I am trying to edit orde {{Order Number}}',
#   'id': 1832},
#  {'class_name': 'REFUND',
#   'question': 'I want to see how long refunds take',
#   'id': 6010},
#  {'class_name': 'CANCEL',
#   'question': 'I do not know what I need to do to check the withdrawal fees',
#   'id': 3446},
#  {'class_name': 'CANCEL',
#   'question': "I'd like to see the withdrwaal fee how can i do it",
#   'id': 3589},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I cannot cancel the corporate newsletter subscrition',
#   'id': 17483},
#  {'class_name': 'ORDER',
#   'question': 'ened help with cancelling purchase {{Order Number}}',
#   'id': 211},
#  {'class_name': 'PAYMENT',
#   'question': 'can ya help me to notify of an error with online payment',
#   'id': 18327},
#  {'class_name': 'CONTACT',
#   'question': "I don't know how to get in touch with customer support",
#   'id': 8706},
#  {'class_name': 'PAYMENT',
#   'question': 'where do I report an error with online payment?',
#   'id': 18813},
#  {'class_name': 'CANCEL',
#   'question': 'I do not know how to see the early termination penalty',
#   'id': 3450},
#  {'class_name': 'ORDER',
#   'question': "I don't know what I need to do to earn some items",
#   'id': 19233},
#  {'class_name': 'ACCOUNT',
#   'question': 'mldifying {{Account Type}} account',
#   'id': 14560},
#  {'class_name': 'PAYMENT',
#   'question': 'need help listing the allowed payment modalities',
#   'id': 5234},
#  {'class_name': 'CONTACT',
#   'question': 'can ya help me speaking to a person',
#   'id': 9091},
#  {'class_name': 'SHIPPING',
#   'question': 'I have a trouble changing my delivery address',
#   'id': 2232},
#  {'class_name': 'INVOICE',
#   'question': 'ido not know what i need to do to get the invoice #12588',
#   'id': 15148},
#  {'class_name': 'ORDER',
#   'question': 'want help deleting something from order {{Order Number}}',
#   'id': 1116},
#  {'class_name': 'ACCOUNT', 'question': 'remove gold account', 'id': 11545},
#  {'class_name': 'DELIVERY',
#   'question': 'assistance to see how soon can I expect my shipment',
#   'id': 13246},
#  {'class_name': 'PAYMENT',
#   'question': "I don't know how to list your allowed payment methods",
#   'id': 5703},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'where do i receive ur company newsletter',
#   'id': 17539},
#  {'class_name': 'CANCEL',
#   'question': 'I need assistance checkng the early exit penalties',
#   'id': 3425},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I cannot see the status of my newsletter subscription',
#   'id': 16955},
#  {'class_name': 'SHIPPING',
#   'question': 'y i cannot set up the secondary shipping address valid',
#   'id': 23544},
#  {'class_name': 'ACCOUNT',
#   'question': "I haven't signed up, I try to create a freemium account",
#   'id': 10676},
#  {'class_name': 'REFUND',
#   'question': 'i try to see how long reimbursements take',
#   'id': 6423},
#  {'class_name': 'ACCOUNT',
#   'question': 'is it possible to inform of an error with registrations',
#   'id': 21551},
#  {'class_name': 'ACCOUNT',
#   'question': 'open a {{Account Type}} acount for my dad',
#   'id': 10447},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'tell me about cancel the newsletter subscription',
#   'id': 17720},
#  {'class_name': 'INVOICE',
#   'question': 'see the bill from {{Person Name}}',
#   'id': 4042},
#  {'class_name': 'CONTACT',
#   'question': 'I do not kinow how to contact a person',
#   'id': 9232},
#  {'class_name': 'ORDER',
#   'question': 'can uhelp me cancelling purchase {{Order Number}}',
#   'id': 812},
#  {'class_name': 'INVOICE',
#   'question': 'get bill fromAnna Freeman',
#   'id': 15435},
#  {'class_name': 'CANCEL',
#   'question': 'i need help to check the cancellation penalty',
#   'id': 3017},
#  {'class_name': 'SHIPPING',
#   'question': 'supports trying to modify theaddress',
#   'id': 2246},
#  {'class_name': 'CANCEL',
#   'question': 'how can I check the termination charge?',
#   'id': 3481},
#  {'class_name': 'INVOICE',
#   'question': 'what do I need to do to download my bills from {{Person Name}}?',
#   'id': 15129},
#  {'class_name': 'INVOICE',
#   'question': 'i want help downloading the bill #85632',
#   'id': 15131},
#  {'class_name': 'CONTACT',
#   'question': 'do you have a mail to get in touch with customer assistance?',
#   'id': 8484},
#  {'class_name': 'REFUND',
#   'question': 'I expect a restitution of {{Currency Symbol}}{{Refund Amount}}, was it processed',
#   'id': 26802},
#  {'class_name': 'CANCEL',
#   'question': 'how to check the cancellation charge',
#   'id': 3791},
#  {'class_name': 'CANCEL',
#   'question': 'wanna check the termination penalties',
#   'id': 3038},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'need assistance subscribing to your newsletter',
#   'id': 17079},
#  {'class_name': 'FEEDBACK',
#   'question': 'help to write a review about a product',
#   'id': 22228},
#  {'class_name': 'SHIPPING',
#   'question': 'i have put the old address by mistkae help me modifying it',
#   'id': 2051},
#  {'class_name': 'DELIVERY',
#   'question': 'can i place an order frim {{Delivery Country}}',
#   'id': 12203},
#  {'class_name': 'REFUND',
#   'question': "I'm waiting for a rebate of {{Currency Symbol}}{{Refund Amount}}",
#   'id': 26037},
#  {'class_name': 'REFUND',
#   'question': 'can i check in which cases can i ask for refunds',
#   'id': 6678},
#  {'class_name': 'REFUND',
#   'question': 'I need to check in which cases can I ask for a reimbursement',
#   'id': 6328},
#  {'class_name': 'CANCEL',
#   'question': "I don't know how to see the early exit charges",
#   'id': 3711},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'can you help me unsubscribing from your company newsletter ?',
#   'id': 17194},
#  {'class_name': 'ACCOUNT',
#   'question': 'I am trying to recover my user profile PIN',
#   'id': 20593},
#  {'class_name': 'PAYMENT',
#   'question': 'can ya help me notify of an issue with payment',
#   'id': 18820},
#  {'class_name': 'ORDER',
#   'question': 'I want to order several articles, could you help me?',
#   'id': 19391},
#  {'class_name': 'PAYMENT',
#   'question': 'how to report errors with payment',
#   'id': 18179},
#  {'class_name': 'REFUND',
#   'question': 'I need to see in what situations can I ask to be refunded',
#   'id': 6377},
#  {'class_name': 'ORDER',
#   'question': 'checking status of order {{Order Number}}',
#   'id': 25063},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'what do I need to do to subscribe to the company newsletter?',
#   'id': 17692},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'help me to unsubscribe from the company newsletter',
#   'id': 17351},
#  {'class_name': 'SHIPPING',
#   'question': 'i have problems changing my shipping addresw',
#   'id': 2689},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'would it be possible to sign up to the newsletter?',
#   'id': 17631},
#  {'class_name': 'CONTACT',
#   'question': 'where do i cherck at what time i can call customer service',
#   'id': 8441},
#  {'class_name': 'FEEDBACK',
#   'question': 'is there a method to leave some feedback for a product?',
#   'id': 22366},
#  {'class_name': 'ORDER',
#   'question': 'can you help me to earn several products?',
#   'id': 19597},
#  {'class_name': 'INVOICE',
#   'question': 'I do not know how to download the bill #12588',
#   'id': 15341},
#  {'class_name': 'PAYMENT',
#   'question': 'how could I inform of errors with payment?',
#   'id': 17922},
#  {'class_name': 'CANCEL',
#   'question': 'I do not know how to see the early termination charge',
#   'id': 3494},
#  {'class_name': 'CANCEL',
#   'question': 'where do i check the withdrawal fees',
#   'id': 3299},
#  {'class_name': 'INVOICE',
#   'question': 'I need assistance downloading invoice #85632',
#   'id': 15158},
#  {'class_name': 'SHIPPING',
#   'question': 'the damn shipping address has changed, can I correct it?',
#   'id': 2934},
#  {'class_name': 'INVOICE',
#   'question': 'i do not know what i have to do to see bill #85632',
#   'id': 4703},
#  {'class_name': 'INVOICE',
#   'question': 'how do I look for bill #12588?',
#   'id': 4622},
#  {'class_name': 'CONTACT',
#   'question': 'i dont know what to do to call customer support',
#   'id': 8819},
#  {'class_name': 'ORDER',
#   'question': 'want help cancelling purchase {{Order Number}}',
#   'id': 929},
#  {'class_name': 'DELIVERY',
#   'question': 'I am calling to see what shipment methods are there',
#   'id': 12419},
#  {'class_name': 'CONTACT',
#   'question': 'i  dont know what i need to do to speak with a live agent',
#   'id': 9525},
#  {'class_name': 'REFUND',
#   'question': 'I need help seeing in which cases can I ask to be reimbursed',
#   'id': 6388},
#  {'class_name': 'CANCEL',
#   'question': 'I have got to see the cancellation charge, can you help me?',
#   'id': 3540},
#  {'class_name': 'CANCEL',
#   'question': 'i have to sede the cancellation charge',
#   'id': 3107},
#  {'class_name': 'ORDER',
#   'question': 'I bought some article, help canceling order {{Order Number}}',
#   'id': 298},
#  {'class_name': 'DELIVERY',
#   'question': 'can i check when my bloody shipment is gonna arrive',
#   'id': 13264},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'help to subscribe to ur company newsletter',
#   'id': 17731},
#  {'class_name': 'ORDER',
#   'question': 'want help to acquire several of your product',
#   'id': 19028},
#  {'class_name': 'CONTACT',
#   'question': 'can yahelp me contacting customer support',
#   'id': 8023},
#  {'class_name': 'PAYMENT',
#   'question': 'how to report an error with online payments',
#   'id': 18686},
#  {'class_name': 'INVOICE',
#   'question': "I don't know what I have to do to see my bill #00108",
#   'id': 4300},
#  {'class_name': 'CANCEL',
#   'question': 'can you help me to see the early termination fees?',
#   'id': 3868},
#  {'class_name': 'FEEDBACK',
#   'question': 'how to make a damn customer claim against your business?',
#   'id': 7203},
#  {'class_name': 'FEEDBACK',
#   'question': 'help me submitting some feedback for your products',
#   'id': 22230},
#  {'class_name': 'ORDER',
#   'question': 'ETA of ordr {{Order Number}}',
#   'id': 25599},
#  {'class_name': 'CANCEL',
#   'question': 'I have to see the early termination charge, can you help me?',
#   'id': 3579},
#  {'class_name': 'INVOICE',
#   'question': 'see bill from {{Person Name}}',
#   'id': 4832},
#  {'class_name': 'ACCOUNT',
#   'question': 'i need assistance changing to the {{Account Type}} account',
#   'id': 24692},
#  {'class_name': 'SHIPPING',
#   'question': 'assistance to set my new shipping address up',
#   'id': 23029},
#  {'class_name': 'ORDER',
#   'question': 'where can i acquire an few of ur article',
#   'id': 19093},
#  {'class_name': 'CANCEL',
#   'question': 'can you help me check the early exit penalties?',
#   'id': 3302},
#  {'class_name': 'ACCOUNT',
#   'question': 'I cannot retrieve the bloody PIN code of my profile',
#   'id': 20569},
#  {'class_name': 'INVOICE',
#   'question': 'want help getting my invoice #85632',
#   'id': 15664},
#  {'class_name': 'CONTACT',
#   'question': 'help seeing what hours customer assistance available is',
#   'id': 8898},
#  {'class_name': 'INVOICE',
#   'question': 'i do not know how to download the damn bills from {{Person Name}}',
#   'id': 15283},
#  {'class_name': 'DELIVERY',
#   'question': 'deliveries to {{Delivery City}}',
#   'id': 12453},
#  {'class_name': 'INVOICE',
#   'question': 'help me download my bills from {{Person Name}}',
#   'id': 15716},
#  {'class_name': 'CANCEL',
#   'question': 'can ushow me the cancellation fees',
#   'id': 3660},
#  {'class_name': 'PAYMENT',
#   'question': 'how to repoft troubles with online payment',
#   'id': 18072},
#  {'class_name': 'FEEDBACK',
#   'question': 'i wabt assistance to send my feedback for a service',
#   'id': 22527},
#  {'class_name': 'CANCEL',
#   'question': 'want assistance checking the cancellation fees',
#   'id': 3550},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I need assistance to unsubscribe to the corporate newsletter',
#   'id': 17402},
#  {'class_name': 'REFUND',
#   'question': 'where to see if there are any updates on my compensation',
#   'id': 26051},
#  {'class_name': 'ACCOUNT',
#   'question': "I don't know what I need to do to change to the {{Account Type}} account",
#   'id': 24144},
#  {'class_name': 'REFUND',
#   'question': 'i expect an refund of {{Refund Amount}} dollars was it processed',
#   'id': 26544},
#  {'class_name': 'REFUND',
#   'question': 'I expect a restitution of {{Refund Amount}} dollars',
#   'id': 26269},
#  {'class_name': 'DELIVERY',
#   'question': 'can I place an order from {{Delivery City}}?',
#   'id': 12457},
#  {'class_name': 'CANCEL',
#   'question': "I'd like tro check the withdrawal fees",
#   'id': 3785},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'help me signing up to the newsletter',
#   'id': 17602},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'help cancelling my corporate newslettersubscription',
#   'id': 17223},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'need help to receive ur company newsletter',
#   'id': 16991},
#  {'class_name': 'SHIPPING',
#   'question': 'assistance correcting my delivery address',
#   'id': 2502},
#  {'class_name': 'DELIVERY',
#   'question': 'can I place an order from {{Delivery City}}?',
#   'id': 11934},
#  {'class_name': 'SHIPPING',
#   'question': 'i need assistance entering a secondary delivery address',
#   'id': 23397},
#  {'class_name': 'ACCOUNT',
#   'question': 'create {{Account Type}} account',
#   'id': 10314},
#  {'class_name': 'CONTACT',
#   'question': 'wanna contact damn customer service i need help',
#   'id': 8659},
#  {'class_name': 'INVOICE',
#   'question': 'i cannot find the invoice from {{Person Name}} find it for me',
#   'id': 4511},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'could ya help me to cancel my newsletter suscription',
#   'id': 17805},
#  {'class_name': 'ACCOUNT',
#   'question': 'problem with {{Account Type}} account terminations',
#   'id': 11010},
#  {'class_name': 'INVOICE',
#   'question': 'help looking for the bill #00108',
#   'id': 4338},
#  {'class_name': 'ACCOUNT',
#   'question': 'I have to reset the access key of my profile',
#   'id': 19917},
#  {'class_name': 'CONTACT',
#   'question': 'what do I have to do to speak to a live agent?',
#   'id': 9294},
#  {'class_name': 'ORDER',
#   'question': 'I want to see the status of order {{Order Number}}, I need help',
#   'id': 25505},
#  {'class_name': 'REFUND',
#   'question': 'I need assistance receiving compensations of my money',
#   'id': 16369},
#  {'class_name': 'FEEDBACK',
#   'question': 'I want to file a consumer claim against your business',
#   'id': 7168},
#  {'class_name': 'SHIPPING',
#   'question': 'there are errors submitting the new shipping address',
#   'id': 23869},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'need help receiving ur cororate newsletter',
#   'id': 17328},
#  {'class_name': 'REFUND',
#   'question': 'when am i gonna obtain a reimbursement of money',
#   'id': 16494},
#  {'class_name': 'CONTACT',
#   'question': 'help talking with customer assistance',
#   'id': 8644},
#  {'class_name': 'FEEDBACK',
#   'question': 'I need assistance to submit my feedback about your products',
#   'id': 22297},
#  {'class_name': 'DELIVERY',
#   'question': 'is it possible to order from {{Delivery Country}}?',
#   'id': 12161},
#  {'class_name': 'CONTACT',
#   'question': 'I ned to speak to customer service',
#   'id': 8038},
#  {'class_name': 'REFUND',
#   'question': 'i do not know hoow i could check ur reimbursement policy',
#   'id': 5917},
#  {'class_name': 'DELIVERY',
#   'question': 'where can i check how soon cn i expect my shipment',
#   'id': 13082},
#  {'class_name': 'REFUND',
#   'question': 'I expect a reimbursmeent of {{Refund Amount}} dollars',
#   'id': 26545},
#  {'class_name': 'FEEDBACK',
#   'question': 'need to submit my feedback for a service can uhelp me',
#   'id': 21889},
#  {'class_name': 'FEEDBACK',
#   'question': 'i want assistancesubmitting my feedback for a product',
#   'id': 21918},
#  {'class_name': 'CANCEL',
#   'question': 'what do I need to do to check the termination charge?',
#   'id': 3181},
#  {'class_name': 'DELIVERY',
#   'question': 'how can I get information about damn delivery  period?',
#   'id': 13317},
#  {'class_name': 'CANCEL',
#   'question': 'can you shlw me the termination charges?',
#   'id': 3126},
#  {'class_name': 'ACCOUNT',
#   'question': 'I want help to reset the password of my user',
#   'id': 20302},
#  {'class_name': 'DELIVERY',
#   'question': 'i need help to see how soon can i expect the parcel',
#   'id': 13065},
#  {'class_name': 'CONTACT',
#   'question': 'i have to contact an agent',
#   'id': 9541},
#  {'class_name': 'DELIVERY',
#   'question': 'i have got to see when mh delivery is gonna arrive',
#   'id': 13563},
#  {'class_name': 'REFUND',
#   'question': 'i expect a compensation of {{Refund Amount}} dollars was it processed',
#   'id': 26775},
#  {'class_name': 'FEEDBACK',
#   'question': 'how could I lodge a reclamation?',
#   'id': 7706},
#  {'class_name': 'DELIVERY',
#   'question': 'I am trying to check how soon can I expct my parcel',
#   'id': 13208},
#  {'class_name': 'FEEDBACK',
#   'question': 'I try to lodge a customer reclamation',
#   'id': 7153},
#  {'class_name': 'PAYMENT',
#   'question': 'what do I have to do to notify of a damn payment problem?',
#   'id': 18336},
#  {'class_name': 'FEEDBACK',
#   'question': 'is it possible to lodge a complaint',
#   'id': 7330},
#  {'class_name': 'ORDER',
#   'question': 'I canno longer afford purchase {{Order Number}}',
#   'id': 937},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'where could I receive the fucking company newsletter?',
#   'id': 17409},
#  {'class_name': 'FEEDBACK',
#   'question': 'I do not know how I can file a claim',
#   'id': 7779},
#  {'class_name': 'DELIVERY',
#   'question': 'i do not know what to do to see how long the shipping takes',
#   'id': 13642},
#  {'class_name': 'CANCEL',
#   'question': 'I have to see the withdrawal penalties, help me',
#   'id': 3624},
#  {'class_name': 'ACCOUNT',
#   'question': 'update data on freemium account',
#   'id': 14380},
#  {'class_name': 'ACCOUNT',
#   'question': 'modify information on {{Account Category}} account',
#   'id': 14734},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'can you help me sign up to the company newsletter?',
#   'id': 17498},
#  {'class_name': 'REFUND',
#   'question': "I don't know how I can ask for restitutions of my money",
#   'id': 15935},
#  {'class_name': 'ORDER',
#   'question': 'i try to see the statuis of purchase {{Order Number}}',
#   'id': 25871},
#  {'class_name': 'FEEDBACK',
#   'question': 'filing customer complaint against ur company',
#   'id': 7837},
#  {'class_name': 'ACCOUNT', 'question': 'delete gold acvount', 'id': 11463},
#  {'class_name': 'SHIPPING',
#   'question': 'I want assistancee trying to modify my shipping address',
#   'id': 2509},
#  {'class_name': 'ORDER',
#   'question': 'i dont want purchase {{Order Number}} could i cancel it',
#   'id': 321},
#  {'class_name': 'ACCOUNT',
#   'question': 'recover the PIN code of my account',
#   'id': 20485},
#  {'class_name': 'FEEDBACK',
#   'question': 'I want help to leave some feedback for a product',
#   'id': 22561},
#  {'class_name': 'ACCOUNT',
#   'question': 'new bloody {{Account Type}} cacount',
#   'id': 10333},
#  {'class_name': 'CANCEL',
#   'question': 'can i sde the termination fee',
#   'id': 3825},
#  {'class_name': 'CONTACT',
#   'question': "I don't know what to do to talk to customer service",
#   'id': 8660},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'where to unsubscribe to your bloody newsletter?',
#   'id': 17520},
#  {'class_name': 'CANCEL',
#   'question': 'could you help me check hte cancellation penalties?',
#   'id': 3860},
#  {'class_name': 'ORDER',
#   'question': 'need help swapping a item of purchase {{Order Number}}',
#   'id': 1174},
#  {'class_name': 'CONTACT',
#   'question': 'help me seeing what hours I can call customer service',
#   'id': 8352},
#  {'class_name': 'DELIVERY',
#   'question': 'where can i find information about the delivery periods',
#   'id': 13575},
#  {'class_name': 'CONTACT',
#   'question': 'I want to speak with customer esrvice',
#   'id': 8153},
#  {'class_name': 'INVOICE', 'question': 'seeing bil #00108', 'id': 4285},
#  {'class_name': 'CANCEL',
#   'question': 'I need help seeing the early termination fee',
#   'id': 3266},
#  {'class_name': 'CANCEL',
#   'question': 'can you help me see the withdrawal penalty?',
#   'id': 3816},
#  {'class_name': 'CONTACT',
#   'question': 'I am trying to speak to an agent',
#   'id': 9206},
#  {'class_name': 'ORDER',
#   'question': 'i want help changing an item of order {{Order Number}}',
#   'id': 1263},
#  {'class_name': 'ACCOUNT',
#   'question': 'editing details on {{Account Type}} account',
#   'id': 14587},
#  {'class_name': 'ACCOUNT',
#   'question': 'update information on {{Account Category}} account',
#   'id': 14516},
#  {'class_name': 'CONTACT',
#   'question': 'I have to contact an operator',
#   'id': 9345},
#  {'class_name': 'CONTACT',
#   'question': 'I want help to talk with customer support',
#   'id': 8145},
#  {'class_name': 'PAYMENT',
#   'question': 'need assistance informing of problems with online payment',
#   'id': 18644},
#  {'class_name': 'INVOICE',
#   'question': 'I want to get my invoice from {{Person Name}}, I need help',
#   'id': 15854},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'how do I subscribe to your newsletter?',
#   'id': 17161},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I want to unsubscribe to your corporate newsletter, help me',
#   'id': 16967},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'give me inormation about my subscription to your newsletter',
#   'id': 17669},
#  {'class_name': 'REFUND',
#   'question': 'help to check the compensation current status',
#   'id': 26855},
#  {'class_name': 'DELIVERY',
#   'question': 'shiping to {{Delivery City}}',
#   'id': 12229},
#  {'class_name': 'PAYMENT',
#   'question': 'how to inform of a payment error?',
#   'id': 18012},
#  {'class_name': 'REFUND',
#   'question': 'help me to check the status of the restitution',
#   'id': 26344},
#  {'class_name': 'INVOICE',
#   'question': 'how can I get the bills from {{Person Name}}?',
#   'id': 15177},
#  {'class_name': 'CANCEL',
#   'question': 'I need help checking the early exit fee',
#   'id': 3625},
#  {'class_name': 'INVOICE',
#   'question': 'i need assistance to locate the bills from {{Person Name}}',
#   'id': 4397},
#  {'class_name': 'INVOICE',
#   'question': 'I do not know what I need to do to get bill #12588',
#   'id': 15317},
#  {'class_name': 'DELIVERY',
#   'question': 'want help seeing how long it takes for my shipment to arrive',
#   'id': 13018},
#  {'class_name': 'REFUND',
#   'question': 'help me to see your goddamn refund policy',
#   'id': 6829},
#  {'class_name': 'FEEDBACK',
#   'question': 'how to file an reclamation?',
#   'id': 6983},
#  {'class_name': 'CANCEL',
#   'question': 'how can i see the early termination penalties',
#   'id': 3509},
#  {'class_name': 'FEEDBACK',
#   'question': 'is there a way to submit bloody feedback for a product?',
#   'id': 22769},
#  {'class_name': 'CANCEL',
#   'question': "I can't find the early terminatuon penalty",
#   'id': 3538},
#  {'class_name': 'CONTACT',
#   'question': "I don't know what to doto speak to someone",
#   'id': 9808},
#  {'class_name': 'SHIPPING',
#   'question': 'I need help trying to edit the shipping address',
#   'id': 2876},
#  {'class_name': 'ACCOUNT',
#   'question': 'create {{Account Category}} account',
#   'id': 10134},
#  {'class_name': 'DELIVERY',
#   'question': 'can ya hepl me see when will my item arrive',
#   'id': 13435},
#  {'class_name': 'REFUND',
#   'question': 'how to track the reimbursement?',
#   'id': 26752},
#  {'class_name': 'SHIPPING',
#   'question': 'I want support chanigng my delivery address',
#   'id': 2302},
#  {'class_name': 'PAYMENT',
#   'question': 'I need assistance to check what payment options you accept',
#   'id': 5129},
#  {'class_name': 'ORDER',
#   'question': 'can uhelp me swappping a product of purchase {{Order Number}}',
#   'id': 1717},
#  {'class_name': 'ORDER',
#   'question': "I can't pay for this item, cancel order {{Order Number}}",
#   'id': 410},
#  {'class_name': 'CONTACT',
#   'question': 'can you help me speaking to an assistant?',
#   'id': 9366},
#  {'class_name': 'CANCEL',
#   'question': 'i cannot find the cancellation fees',
#   'id': 3586},
#  {'class_name': 'SHIPPING',
#   'question': 'I want help entering the delivery address',
#   'id': 23703},
#  {'class_name': 'PAYMENT',
#   'question': 'how do I report errors with online payments ?',
#   'id': 18041},
#  {'class_name': 'ACCOUNT', 'question': 'new platinum account', 'id': 10176},
#  {'class_name': 'ORDER',
#   'question': 'assistance to update purchase {{Order Number}}',
#   'id': 1876},
#  {'class_name': 'CONTACT',
#   'question': 'i need assistance to talk with someone',
#   'id': 8967},
#  {'class_name': 'DELIVERY',
#   'question': 'do you deliver to {{Delivery City}}?',
#   'id': 12338},
#  {'class_name': 'INVOICE',
#   'question': 'i dont know what to do  to download bill #85632',
#   'id': 15608},
#  {'class_name': 'CANCEL',
#   'question': 'I need help to see the early exit penalties',
#   'id': 2998},
#  {'class_name': 'CANCEL',
#   'question': 'I need to see the cancellation fees',
#   'id': 3408},
#  {'class_name': 'PAYMENT',
#   'question': 'I need assistance listing the available payment methods',
#   'id': 5805},
#  {'class_name': 'CONTACT',
#   'question': 'can you help me talk to an operator?',
#   'id': 9450},
#  {'class_name': 'CANCEL', 'question': 'withrdawal penalty', 'id': 3349},
#  {'class_name': 'CONTACT',
#   'question': "I don't know how I can cotnact somebody",
#   'id': 8943},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'need help cancelling my subscription to ur newsletter',
#   'id': 17655},
#  {'class_name': 'INVOICE',
#   'question': 'i do not know how i can download my invoice #00108',
#   'id': 15235},
#  {'class_name': 'DELIVERY',
#   'question': 'shipmetns to {{Delivery City}}',
#   'id': 12431},
#  {'class_name': 'CANCEL',
#   'question': 'assistance checking the fucking early exit penalties',
#   'id': 3203},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'i have got to cancel the company newsletter subscription',
#   'id': 17318},
#  {'class_name': 'CANCEL',
#   'question': 'I need help to check the early exit penalty',
#   'id': 3526},
#  {'class_name': 'ORDER',
#   'question': 'where could I cancel purchase {{Order Number}}?',
#   'id': 811},
#  {'class_name': 'PAYMENT',
#   'question': "I don't know how to see your allowed payment modalities",
#   'id': 5622},
#  {'class_name': 'INVOICE',
#   'question': 'I do not know how I can download the invoices from {{Person Name}}',
#   'id': 15354},
#  {'class_name': 'REFUND',
#   'question': 'can ya show me in what cases can i ask for a reimbursement',
#   'id': 6681},
#  {'class_name': 'ORDER',
#   'question': 'I do not know what to do to earn several of yoru item',
#   'id': 19649},
#  {'class_name': 'CONTACT',
#   'question': 'I need to speak with a human agent',
#   'id': 9031},
#  {'class_name': 'SHIPPING',
#   'question': 'i need help entering another delivery address',
#   'id': 23492},
#  {'class_name': 'INVOICE',
#   'question': 'send me my bill from {{Person Name}}',
#   'id': 15097},
#  {'class_name': 'FEEDBACK',
#   'question': 'can I leave some feedback about a product?',
#   'id': 22416},
#  {'class_name': 'SHIPPING',
#   'question': "I don't know what I need to do to enter the shipping address",
#   'id': 23729},
#  {'class_name': 'PAYMENT',
#   'question': 'how can I check what payment methods are allowed?',
#   'id': 5501},
#  {'class_name': 'DELIVERY',
#   'question': 'I need assistance checking how soon can I expect my product',
#   'id': 13262},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I need to receive thecorporate newsletter',
#   'id': 17331},
#  {'class_name': 'ORDER',
#   'question': 'I need to purchase some bloody products',
#   'id': 19765},
#  {'class_name': 'CONTACT',
#   'question': 'i want help to get in touch with customer service',
#   'id': 8721},
#  {'class_name': 'INVOICE',
#   'question': 'I do not know what I have to do to look for the bill #12588',
#   'id': 4677},
#  {'class_name': 'ACCOUNT',
#   'question': 'i need help notifying of problems with a signup',
#   'id': 21595},
#  {'class_name': 'REFUND',
#   'question': 'I am trying to check in what cases can I request a refund',
#   'id': 6367},
#  {'class_name': 'PAYMENT',
#   'question': 'want assistance informing of problems with payments',
#   'id': 18239},
#  {'class_name': 'FEEDBACK',
#   'question': 'can you help me make a claim against your company?',
#   'id': 7584},
#  {'class_name': 'REFUND',
#   'question': 'see in what situations can I ask to be refunded',
#   'id': 6327},
#  {'class_name': 'DELIVERY',
#   'question': 'deliveries to {{Delivery Country}}',
#   'id': 12004},
#  {'class_name': 'REFUND',
#   'question': 'assistance checking in which cases can i ask to be refunded',
#   'id': 6438},
#  {'class_name': 'ACCOUNT',
#   'question': 'how do I recover my account PIN code?',
#   'id': 20461},
#  {'class_name': 'FEEDBACK',
#   'question': 'can I send some feedback for a service?',
#   'id': 22083},
#  {'class_name': 'INVOICE',
#   'question': 'see the bill from {{Person Name}}',
#   'id': 4633},
#  {'class_name': 'REFUND',
#   'question': 'how can I ask for a compensation of money?',
#   'id': 16320},
#  {'class_name': 'ACCOUNT',
#   'question': 'what do i have to do to delete the {{Account Category}} account',
#   'id': 11132},
#  {'class_name': 'SHIPPING',
#   'question': 'there is an issue setting up the secondary delivery address',
#   'id': 23451},
#  {'class_name': 'CONTACT',
#   'question': 'what do I have to do to talk with an agent?',
#   'id': 9579},
#  {'class_name': 'INVOICE',
#   'question': 'i want assistance downloading the bills from {{Person Name}}',
#   'id': 15888},
#  {'class_name': 'CONTACT',
#   'question': 'I would like to call customer service, how to do it?',
#   'id': 8469},
#  {'class_name': 'CANCEL',
#   'question': 'what is the early exit penalty',
#   'id': 3044},
#  {'class_name': 'CONTACT',
#   'question': 'I have to talk with a person',
#   'id': 9633},
#  {'class_name': 'DELIVERY',
#   'question': "I don't know how to see when my item is going to arrive",
#   'id': 13636},
#  {'class_name': 'FEEDBACK',
#   'question': 'need asistance filing a consumer claim against your business',
#   'id': 7496},
#  {'class_name': 'CONTACT',
#   'question': "I don't know how to speak with a humnan agent",
#   'id': 9426},
#  {'class_name': 'ACCOUNT',
#   'question': 'can uhelp me retrieving my account pin',
#   'id': 20134},
#  {'class_name': 'SHIPPING',
#   'question': 'I chose a wrong delivery address, can you help me update it?',
#   'id': 2362},
#  {'class_name': 'DELIVERY',
#   'question': 'can I order from {{Delivery Country}}?',
#   'id': 12703},
#  {'class_name': 'FEEDBACK',
#   'question': 'wanna file a consumer complaint aganst ur organization',
#   'id': 7644},
#  {'class_name': 'FEEDBACK',
#   'question': 'I need help leaving my fucking feedback about a product',
#   'id': 22379},
#  {'class_name': 'SHIPPING',
#   'question': 'issue changing shipping address',
#   'id': 2207},
#  {'class_name': 'SHIPPING',
#   'question': 'I have an error updating my fucking shipping address',
#   'id': 2605},
#  {'class_name': 'PAYMENT',
#   'question': 'I want help to notify of an issue with payments',
#   'id': 18124},
#  {'class_name': 'SHIPPING',
#   'question': 'can ya help me to set the nw shipping address up',
#   'id': 23341},
#  {'class_name': 'ORDER',
#   'question': 'help me checking the status of purchase {{Order Number}}',
#   'id': 25186},
#  {'class_name': 'PAYMENT',
#   'question': 'want help to  list ur accepted payment options',
#   'id': 4983},
#  {'class_name': 'REFUND',
#   'question': "I'm waiting for a rebate of {{Currency Symbol}}{{Refund Amount}}",
#   'id': 25896},
#  {'class_name': 'INVOICE',
#   'question': 'how can i take a quick look at invoice #85632',
#   'id': 4662},
#  {'class_name': 'FEEDBACK',
#   'question': 'want helpmaking a consumer reclamation against ur company',
#   'id': 7908},
#  {'class_name': 'CONTACT',
#   'question': 'where do I check what hours I can call customer assistance?',
#   'id': 8221},
#  {'class_name': 'CONTACT',
#   'question': "I don't know what I need to do to chat with an operator",
#   'id': 9520},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'need assistance cancelling my subscription to ur newsletter',
#   'id': 17515},
#  {'class_name': 'REFUND', 'question': 'any news on the refund', 'id': 26455},
#  {'class_name': 'DELIVERY',
#   'question': 'I am trying to check how soon can I expect my parcel',
#   'id': 13081},
#  {'class_name': 'SUBSCRIPTION',
#   'question': 'I want help unsubscribing from the company newsletter',
#   'id': 17277},
#  {'class_name': 'DELIVERY',
#   'question': 'I am calling to see how soon can I expect the shipment',
#   'id': 13717},
#  {'class_name': 'ACCOUNT',
#   'question': 'change to {{Account Category}} account',
#   'id': 24443},
#  {'class_name': 'REFUND',
#   'question': 'I want help to ask for my money back',
#   'id': 16445},
#  {'class_name': 'FEEDBACK',
#   'question': 'I am unhappy with your work, lodge a claim',
#   'id': 7258},
#  {'class_name': 'FEEDBACK',
#   'question': 'do you have a method to send some feedback for a product ?',
#   'id': 22055},
#  {'class_name': 'SHIPPING',
#   'question': 'there are troubles correcting the shipping address',
#   'id': 2524},
#  {'class_name': 'REFUND',
#   'question': 'I have got to see how long refunds take, I need help',
#   'id': 6424},
#  {'class_name': 'CONTACT',
#   'question': 'I want to contact an agent',
#   'id': 9146},
#  {'class_name': 'REFUND',
#   'question': 'can I check your refund policy?',
#   'id': 6350},
#  {'class_name': 'INVOICE',
#   'question': 'need to locate my invoice #37777 how do i do it',
#   'id': 4351},
#  {'class_name': 'CONTACT',
#   'question': 'can I check what hours I can reach customer support?',
#   'id': 8618},
#  {'class_name': 'FEEDBACK',
#   'question': 'help me filing a complaint',
#   'id': 7352},
#  {'class_name': 'REFUND',
#   'question': 'I have paid {{Currency Symbol}}{{Refund Amount}} for this item, help me to obtain a rebate',
#   'id': 16880},
#  {'class_name': 'PAYMENT',
#   'question': 'how do I list the allowed payment methods?',
#   'id': 5223},
#  {'class_name': 'CONTACT',
#   'question': 'do you have a number to contact goddamn customer assistance?',
#   'id': 8498},
#  {'class_name': 'REFUND',
#   'question': 'can you help me get a restitution of my money?',
#   'id': 16751},
#  {'class_name': 'PAYMENT',
#   'question': 'help to solve an error withonline payments',
#   'id': 18153},
#  {'class_name': 'ORDER',
#   'question': "I don't know what to do to earn some of your item",
#   'id': 19616}]

# %%
# Jinja2 template of our prompt for optimizing the system prompt
# + adding few shot examples to increase the performance of the model
template = r"""<START_OF_SYSTEM_MESSAGE>
 {{system_prompt}}
 {% if output_format_str is not none %}
 {{output_format_str}}
 {% endif %}
 {% if few_shot_demos is not none %}
 Here are some examples:
 {{few_shot_demos}}
 {% endif %}
 <END_OF_SYSTEM_MESSAGE>
 <START_OF_USER_MESSAGE>
 {{input_str}}
 <END_OF_USER_MESSAGE>
 """

task_desc_template = r"""You are a classifier. Given a question, you need to classify it into one of the following classes:
 {% if classes %}
 {% for class in classes %}
 - {{class.label}}
 {% endfor %}
 {% endif %}
 Do not try to answer the question.
 """

from adalflow.datasets.types import BaseData
from dataclasses import dataclass, field

@dataclass
class ClassificationDataClass(BaseData):
    question: str = field(
        metadata={"desc": "The question to be classified"},
        default=None,
    )
    class_name: str = field(
        metadata={"desc": "The name of the class to which the question belongs"},
        default=None,
    )
    rationale: str = field(
         metadata={
             "desc": "Your step-by-step reasoning to classify the question to class_name"
         },
         default=None,
     )
    __input_fields__ = ["question"]
    __output_fields__ = ["rationale", "class_name"] # it is important to have the rationale before the class_name


# convert each record to a ClassificationDataClass object, and end up with a list of ClassificationDataClass objects
df_train = pd.read_csv("train.csv")
train_dataset = [ClassificationDataClass( **record ) for record in df_train.to_dict(orient="records")]
val_dataset = [ClassificationDataClass( **record ) for record in pd.read_csv("val.csv").to_dict(orient="records")]
test_dataset = [ClassificationDataClass( **record ) for record in pd.read_csv("test.csv").to_dict(orient="records")]

CLASSES = df_train["class_name"].value_counts()
CLASSES
# Out:
# class_name
# INVOICE         57
# PAYMENT         56
# DELIVERY        55
# FEEDBACK        55
# REFUND          55
# ACCOUNT         50
# CONTACT         49
# CANCEL          46
# SHIPPING        43
# ORDER           42
# SUBSCRIPTION    42
# Name: count, dtype: int64

# %% [markdown]
# We define an adaflow component to call the llm and request to classify a question.

# %%
from typing import List, Dict, Optional, Union, Tuple, Callable, Any
import adalflow as adal


class ClassificationStructuredOutput(adal.Component):
    
     def __init__(self, classes: List[str], data_class: ClassificationDataClass, model_client: adal.ModelClient, model_kwargs: Dict):
         super().__init__()
         
         task_desc_str = adal.Prompt(
             template=task_desc_template, prompt_kwargs={"classes":  [
             {"label": label}
             for label in classes
         ]}
         )()

         self.data_class = data_class
         self.data_class.set_task_desc(task_desc_str)

         self.parser = adal.DataClassParser(
             data_class=self.data_class, return_data_class=True, format_type="yaml"
         )

         prompt_kwargs = {
             "system_prompt": adal.Parameter(
                 data=self.parser.get_task_desc_str(),
                 role_desc="Task description",
                 requires_opt=True,
                 param_type=adal.ParameterType.PROMPT,
             ),
             "output_format_str": adal.Parameter(
                 data=self.parser.get_output_format_str(),
                 role_desc="Output format requirements",
                 requires_opt=False,
                 param_type=adal.ParameterType.PROMPT,
             ),
             "few_shot_demos": adal.Parameter(
                 data=None,
                 requires_opt=True,
                 role_desc="Few shot examples to help the model",
                 param_type=adal.ParameterType.DEMOS,
             ),
         }

         self.llm = adal.Generator(
             model_client=model_client,
             model_kwargs=model_kwargs,
             prompt_kwargs=prompt_kwargs,
             template=template,
             output_processors=self.parser,
             use_cache=True,
         )

     def _prepare_input(self, question: str):
         input_data = self.data_class(question=question)
         input_str = self.parser.get_input_str(input_data)
         prompt_kwargs = {
             "input_str": adal.Parameter(
                 data=input_str, requires_opt=False, role_desc="input to the LLM"
             )
         }
         return prompt_kwargs

     def call(
         self, question: str, id: Optional[str] = None
     ) -> Union[adal.GeneratorOutput, adal.Parameter]:
         prompt_kwargs = self._prepare_input(question)
         output = self.llm(prompt_kwargs=prompt_kwargs, id=id)
         return output

# %% [markdown]
# We define a component that will be used to train the model. This component will use the ClassificationStructuredOutput component to classify the questions.

# %%
from adalflow.eval.answer_match_acc import AnswerMatchAcc

class ClassificationComponent(adal.AdalComponent):
    def __init__(
        self,
        classification_structured_output: ClassificationStructuredOutput,
        teacher_model_config: Dict,
        backward_engine_model_config: Dict,
        text_optimizer_model_config: Dict,
    ):
        task = classification_structured_output
        # We use the exact match accuracy as the evaluation metric, it's either 1 or 0.
        eval_fn = AnswerMatchAcc(type="exact_match").compute_single_item
        # Returns a float in range [0, 1], and the higher the better.
        loss_fn = adal.EvalFnToTextLoss(
            eval_fn=eval_fn,
            eval_fn_desc="exact_match: 1 if str(y) == str(y_gt) else 0",
        )
        super().__init__(
            task=task,
            eval_fn=eval_fn,
            loss_fn=loss_fn,
            backward_engine_model_config=backward_engine_model_config,
            text_optimizer_model_config=text_optimizer_model_config,
            teacher_model_config=teacher_model_config,
        )

    def handle_one_task_sample(self, sample: ClassificationDataClass):
        """We return a tuple of the call function and the kwargs to be passed to the call function.
        You can find the implementation of the call function in the ClassificationStructuredOutput class."""
        return self.task.call, {"question": sample.question, "id": sample.id}

    def evaluate_one_sample(
        self, sample: ClassificationDataClass, y_pred: adal.GeneratorOutput
    ) -> float:
        """We evaluate the model's prediction on a single sample. We return a float value as the evaluation metric."""
        y_label = -1
        if y_pred and y_pred.data is not None and y_pred.data.class_name is not None:
            y_label = y_pred.data.class_name
        return self.eval_fn(y_label, sample.class_name)

    def handle_one_loss_sample(
        self, sample: ClassificationDataClass, y_pred: adal.Parameter, *args, **kwargs
    ) -> Tuple[Callable[..., Any], Dict]:
        """We return a tuple of the loss function and the kwargs to be passed to the loss function."""
        full_response = y_pred.full_response
        y_label = -1
        if (
            full_response
            and full_response.data is not None
            and full_response.data.class_name is not None
        ):
            y_label = full_response.data.class_name

        y_pred.eval_input = y_label
        y_gt = adal.Parameter(
            name="y_gt",
            data=sample.class_name,
            eval_input=sample.class_name,
            requires_opt=False,
        )
        return self.loss_fn, {"kwargs": {"y": y_pred, "y_gt": y_gt}}

    def configure_teacher_generator(self):
        super().configure_teacher_generator_helper(**self.teacher_model_config)

    def configure_backward_engine(self):
        super().configure_backward_engine_helper(**self.backward_engine_model_config)

    def configure_optimizers(self):
        to = super().configure_text_optimizer_helper(**self.text_optimizer_model_config)
        do = super().configure_demo_optimizer_helper()
        return to + do

# %%
from datasets import Dataset

def train(
    classification_component: ClassificationComponent,
    train_dataset: Dataset,
    test_dataset: Dataset = None,
    val_dataset: Dataset = None,
    train_batch_size=4,  # larger batch size is not that effective, probably because of llm's lost in the middle
    raw_shots: int = 0,
    bootstrap_shots: int = 1,
    max_steps=12,
    num_workers=1,
    strategy="constrained",
    optimization_order="sequential",
    debug=False,
):

    trainer = adal.Trainer(
        train_batch_size=train_batch_size,
        adaltask=classification_component,
        strategy=strategy,
        max_steps=max_steps,
        num_workers=num_workers,
        raw_shots=raw_shots,
        bootstrap_shots=bootstrap_shots,
        debug=debug,
        weighted_sampling=True,
        optimization_order=optimization_order,
        exclude_input_fields_from_bootstrap_demos=True,
    )
    trainer.fit(
        train_dataset=train_dataset,
        val_dataset=val_dataset,
        test_dataset=test_dataset,
        debug=debug,
    )
    return trainer
    
from adalflow.components.model_client.openai_client import OpenAIClient

gpt_4o_mini_model = {
    "model_client": OpenAIClient(input_type="text"),
    "model_kwargs": {
        "model": "gpt-4o-mini",
        "max_tokens": 2000,
        "temperature": 0.0,
        "top_p": 0.99,
        "frequency_penalty": 0,
        "presence_penalty": 0,
        "stop": None,
    },
}


gpt_4o_model = {
    "model_client": OpenAIClient(),
    "model_kwargs": {
        "model": "gpt-4o",
        "temperature": 1,
        "top_p": 0.99,
        "max_tokens": 1000,
        # "frequency_penalty": 1,  # high for nto repeating prompt
    },
}

# Config for generating the classification
classification_structured_output = ClassificationStructuredOutput(
    **gpt_4o_mini_model,
    classes=CLASSES,
    data_class=ClassificationDataClass,
)
    
# Config for the training configuration
classification_component = ClassificationComponent(
    classification_structured_output=classification_structured_output,
    text_optimizer_model_config=gpt_4o_model,
    backward_engine_model_config=gpt_4o_model,
    teacher_model_config=gpt_4o_model,
)


train_object = train(
    classification_component=classification_component,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    test_dataset=test_dataset,
    debug=False,
    max_steps=12,
    strategy="constrained",
    optimization_order="sequential"
)
# Out:
# output_format_str: Your output should be formatted as a standard YAML instance with the following schema:
# ```
# rationale: Your step-by-step reasoning to classify the question to class_name (str) (optional)
# class_name: The name of the class to which the question belongs (str) (optional)
# ```
# -Make sure to always enclose the YAML output in triple backticks (```). Please do not add anything other than valid YAML output!
# -Follow the YAML formatting conventions with an indent of 2 spaces.
# -DO NOT mistaken the "properties" and "type" in the schema as the actual fields in the YAML output.
# -Quote the string values properly.
# cache_path: /Users/vincent/.adalflow/cache_OpenAIClient_gpt-4o-mini.db
# raw_shots: 0, bootstrap_shots: 1
# cache_path: /Users/vincent/.adalflow/cache_OpenAIClient_gpt-4o.db
# cache_path: /Users/vincent/.adalflow/cache_OpenAIClient_gpt-4o.db
# Configuring teacher generator for Generator(
#   model_kwargs={'model': 'gpt-4o', 'temperature': 1, 'top_p': 0.99, 'max_tokens': 1000},
#   (prompt): Prompt(
#     template: <START_OF_SYSTEM_MESSAGE>
#      {{system_prompt}}
#      {% if output_format_str is not none %}
#      {{output_format_str}}
#      {% endif %}
#      {% if few_shot_demos is not none %}
#      Here are some examples:
#      {{few_shot_demos}}
#      {% endif %}
#      <END_OF_SYSTEM_MESSAGE>
#      <START_OF_USER_MESSAGE>
#      {{input_str}}
#      <END_OF_USER_MESSAGE>
#      , prompt_kwargs: {'system_prompt': 'You are a classifier. Given a question, you need to classify it into one of the following classes:\n - 57\n - 56\n - 55\n - 55\n - 55\n - 50\n - 49\n - 46\n - 43\n - 42\n - 42\n Do not try to answer the question.\n ', 'output_format_str': 'Your output should be formatted as a standard YAML instance with the following schema:\n```\nrationale: Your step-by-step reasoning to classify the question to class_name (str) (optional)\nclass_name: The name of the class to which the question belongs (str) (optional)\n```\n-Make sure to always enclose the YAML output in triple backticks (```). Please do not add anything other than valid YAML output!\n-Follow the YAML formatting conventions with an indent of 2 spaces.\n-DO NOT mistaken the "properties" and "type" in the schema as the actual fields in the YAML output.\n-Quote the string values properly.', 'few_shot_demos': 'None'}, prompt_variables: ['few_shot_demos', 'input_str', 'system_prompt', 'output_format_str']
#   )
#   (model_client): OpenAIClient()
#   (output_processors): DataClassParser(
#     data_class=ClassificationDataClass, format_type=yaml,            return_data_class=True, input_fields=['question'],            output_fields=['rationale', 'class_name']
#     (_output_processor): YamlParser()
#     (output_format_prompt): Prompt(
#       template: Your output should be formatted as a standard YAML instance with the following schema:
#       ```
#       {{schema}}
#       ```
#       -Make sure to always enclose the YAML output in triple backticks (```). Please do not add anything other than valid YAML output!
#       -Follow the YAML formatting conventions with an indent of 2 spaces.
#       -DO NOT mistaken the "properties" and "type" in the schema as the actual fields in the YAML output.
#       -Quote the string values properly., prompt_variables: ['schema']
#     )
#   )
# )
# Teacher generator set: Generator(
#   model_kwargs={'model': 'gpt-4o', 'temperature': 1, 'top_p': 0.99, 'max_tokens': 1000},
#   (prompt): Prompt(
#     template: <START_OF_SYSTEM_MESSAGE>
#      {{system_prompt}}
#      {% if output_format_str is not none %}
#      {{output_format_str}}
#      {% endif %}
#      {% if few_shot_demos is not none %}
#      Here are some examples:
#      {{few_shot_demos}}
#      {% endif %}
#      <END_OF_SYSTEM_MESSAGE>
#      <START_OF_USER_MESSAGE>
#      {{input_str}}
#      <END_OF_USER_MESSAGE>
#      , prompt_kwargs: {'system_prompt': 'You are a classifier. Given a question, you need to classify it into one of the following classes:\n - 57\n - 56\n - 55\n - 55\n - 55\n - 50\n - 49\n - 46\n - 43\n - 42\n - 42\n Do not try to answer the question.\n ', 'output_format_str': 'Your output should be formatted as a standard YAML instance with the following schema:\n```\nrationale: Your step-by-step reasoning to classify the question to class_name (str) (optional)\nclass_name: The name of the class to which the question belongs (str) (optional)\n```\n-Make sure to always enclose the YAML output in triple backticks (```). Please do not add anything other than valid YAML output!\n-Follow the YAML formatting conventions with an indent of 2 spaces.\n-DO NOT mistaken the "properties" and "type" in the schema as the actual fields in the YAML output.\n-Quote the string values properly.', 'few_shot_demos': 'None'}, prompt_variables: ['few_shot_demos', 'input_str', 'system_prompt', 'output_format_str']
#   )
#   (model_client): OpenAIClient()
#   (output_processors): DataClassParser(
#     data_class=ClassificationDataClass, format_type=yaml,            return_data_class=True, input_fields=['question'],            output_fields=['rationale', 'class_name']
#     (_output_processor): YamlParser()
#     (output_format_prompt): Prompt(
#       template: Your output should be formatted as a standard YAML instance with the following schema:
#       ```
#       {{schema}}
#       ```
#       -Make sure to always enclose the YAML output in triple backticks (```). Please do not add anything other than valid YAML output!
#       -Follow the YAML formatting conventions with an indent of 2 spaces.
#       -DO NOT mistaken the "properties" and "type" in the schema as the actual fields in the YAML output.
#       -Quote the string values properly., prompt_variables: ['schema']
#     )
#   )
# ), teacher Generator(
#   model_kwargs={'model': 'gpt-4o', 'temperature': 1, 'top_p': 0.99, 'max_tokens': 1000},
#   (prompt): Prompt(
#     template: <START_OF_SYSTEM_MESSAGE>
#      {{system_prompt}}
#      {% if output_format_str is not none %}
#      {{output_format_str}}
#      {% endif %}
#      {% if few_shot_demos is not none %}
#      Here are some examples:
#      {{few_shot_demos}}
#      {% endif %}
#      <END_OF_SYSTEM_MESSAGE>
#      <START_OF_USER_MESSAGE>
#      {{input_str}}
#      <END_OF_USER_MESSAGE>
#      , prompt_kwargs: {'system_prompt': 'You are a classifier. Given a question, you need to classify it into one of the following classes:\n - 57\n - 56\n - 55\n - 55\n - 55\n - 50\n - 49\n - 46\n - 43\n - 42\n - 42\n Do not try to answer the question.\n ', 'output_format_str': 'Your output should be formatted as a standard YAML instance with the following schema:\n```\nrationale: Your step-by-step reasoning to classify the question to class_name (str) (optional)\nclass_name: The name of the class to which the question belongs (str) (optional)\n```\n-Make sure to always enclose the YAML output in triple backticks (```). Please do not add anything other than valid YAML output!\n-Follow the YAML formatting conventions with an indent of 2 spaces.\n-DO NOT mistaken the "properties" and "type" in the schema as the actual fields in the YAML output.\n-Quote the string values properly.', 'few_shot_demos': 'None'}, prompt_variables: ['few_shot_demos', 'input_str', 'system_prompt', 'output_format_str']
#   )
#   (model_client): OpenAIClient()
#   (output_processors): DataClassParser(
#     data_class=ClassificationDataClass, format_type=yaml,            return_data_class=True, input_fields=['question'],            output_fields=['rationale', 'class_name']
#     (_output_processor): YamlParser()
#     (output_format_prompt): Prompt(
#       template: Your output should be formatted as a standard YAML instance with the following schema:
#       ```
#       {{schema}}
#       ```
#       -Make sure to always enclose the YAML output in triple backticks (```). Please do not add anything other than valid YAML output!
#       -Follow the YAML formatting conventions with an indent of 2 spaces.
#       -DO NOT mistaken the "properties" and "type" in the schema as the actual fields in the YAML output.
#       -Quote the string values properly., prompt_variables: ['schema']
#     )
#   )
# )
# Teacher generator configured.
# cache_path: /Users/vincent/.adalflow/cache_OpenAIClient_gpt-4o.db
# Backward engine configured for all generators.
# Loading Data: 100%|██████████| 495/495 [00:00<00:00, 1441.61it/s]
# Evaluating step(0): 0.0 across 19 samples, Max potential: 0.9616:   4%|▍         | 19/495 [00:12<05:07,  1.55it/s]

# %%
import json
ckpt_file = json.load(open(train_object.ckpt_file))

# %%
test_scores = ckpt_file["test_scores"]

# %%
import matplotlib.pyplot as plt

methods = ["system prompt optimization"] * 12 + [
    "few-shot examples optimization"
] * 12
plt.figure(figsize=(10, 6))
plt.plot(
    range(1, 13),
    test_scores[:12],
    marker="o",
    label="system prompt optimization",
)
plt.plot(
    range(13, 25),
    test_scores[12:24],
    marker="o",
    label="few-shot examples optimization",
)

plt.axvline(x=12.5, color="gray", linestyle="--")  # Divider between methods

plt.xlabel("Steps")
plt.ylabel("Test Accuracy")
plt.title("Sequential Optimization of system prompts + few-shots")
plt.legend()
plt.grid(True)

plt.show()
